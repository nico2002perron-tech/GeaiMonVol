# %% [markdown]
# **Exercice 1 :**

# %% [markdown]
# Écrivez un programme qui demande d'entrer un chiffre entier et renvoie un message dépendamment s'il est pair ou impair.

# %% [markdown]
# **Exercice 2 :**

# %% [markdown]
# Écrivez un programme avec une instruction `if-elif-else` qui demande de combien le marché a varié aujourd'hui via la fonction `input()` et faites imprimer des messages selon si le marché a baissé, augmenté ou resté stable. Le message imprimé dépend si le chiffre entré est négatif, positif ou nul.

# %% [markdown]
# **Exercice 3:**

# %% [markdown]
# Vous disposez du dictionnaire suivant sur le chiffres d'affaires **en millions** de quelques entreprises. Écrivez un programme qui donne deux listes d'entreprises. Dans la première liste on trouve les entreprises dont le chiffres d'affaires est supérieur à 100 milliards $ US et les autres dans la deuxième liste.

# %%
ventes = {"Microsoft": 168088, "Apple": 365817, "Oracle": 40479, "IBM": 57350, "Meta": 117929, "Salesforce": 21252, "Alphabet": 257637, "Banque Royal": 22721, "Suncor": 19373, "TD": 23880, "Shopify": 2929}
liste1 = []
liste2 = []

for i in ventes:
    if ventes[i] > ...
# Out:
# liste1 ['Microsoft', 'Apple', 'Meta', 'Alphabet']
# liste1 ['Oracle', 'IBM', 'Salesforce', 'Banque Royal', 'Suncor', 'TD', 'Shopify']

# %% [markdown]
# **Exercice 4:**
#
# Vous disposez de la liste suivante des rendements journaliers de Microsoft.
#
# Écrivez un programme qui imprime le message suivant : " Pendant les n derniers jours, le rendement journalier de Microsoft était positif m fois. n et m à trouver par votre code.

# %%
rend_MSFT = [0.0084, -0.01631, 0.01556, -0.03895, 0.01522, -0.0071, 0.0088, 0.0280 ,0.0105, 0.028493, -0.0265, 0.0011, -0.0184, -0.0057, 0.0022, -0.0243, 0.0177, -0.0423]

compter = 0

for i in range(len(rend_MSFT)):
    if ...
# Out:
# 18 10
